# %%
### Dependencies and Configuration ###

#from config import password2
#from config import pw2
from sqlalchemy import create_engine

import pandas as pd
import numpy as np
import matplotlib 
#import pyplot as plt

# %%
#### IMPORT DATA #####
# Using panda red_excel to import the data from the excel file

EXCEL_PATH = 'data/ATLAS/FoodEnvironmentAtlas.xls'
VARIABLE_PATH = 'data/ATLAS/variables.csv'


# Import entire excel files as dataframes

global_dict = pd.read_excel(EXCEL_PATH,
sheet_name=['Supplemental Data - County','ACCESS', 'STORES', 'RESTAURANTS', 'ASSISTANCE', 'INSECURITY', 'LOCAL', 'HEALTH', 'SOCIOECONOMIC'])


#global_dict

# %%
## CLEANING DATA ##
### LISTS OF COLUMNS I WANT FROM EACH SHEET ####

POPULATION_LIST = ['County',
'State',
'2010_Census_Population',
'Population_Estimate_2011',
'Population_Estimate_2012',
'Population_Estimate_2013',
'Population_Estimate_2014',
'Population_Estimate_2015',
'Population_Estimate_2016',
'Population_Estimate_2017',
'Population_Estimate_2018'
]

ACCESS_LIST = ['FIPS',
'PCT_LACCESS_POP10',
'PCT_LACCESS_POP15',
'PCT_LACCESS_LOWI10',
'PCT_LACCESS_LOWI15',
'PCT_LACCESS_HHNV10',
'PCT_LACCESS_HHNV15',
'PCT_LACCESS_SNAP15']

STORES_LIST = [
'GROCPTH11',
'GROCPTH16',
'SUPERCPTH11',
'SUPERCPTH16',
'CONVSPTH11',
'CONVSPTH16',
'SNAPSPTH12',
'SNAPSPTH17',
'WICSPTH11',
'WICSPTH16']

RESTAURANTS_LIST = ['FFRPTH11',
'FFRPTH16',
'FSRPTH11',
'FSRPTH16',
'PC_FFRSALES07',
'PC_FFRSALES12',
'PC_FSRSALES07',
'PC_FSRSALES12']

ASSISTANCE_LIST = [
'REDEMP_SNAPS12',
'REDEMP_SNAPS17',
'PCT_SNAP12',
'PCT_SNAP17',
'PC_SNAPBEN12',
'PC_SNAPBEN17',
'SNAP_PART_RATE11',
'SNAP_PART_RATE16',
'PC_WIC_REDEMP11',
'PC_WIC_REDEMP16',
'REDEMP_WICS11',
'REDEMP_WICS16',
'PCT_WIC12',
'PCT_WIC17',
'PCT_WICINFANTCHILD14',
'PCT_WICINFANTCHILD16',
'FOOD_BANKS18']

INSECURITY_LIST = [
'FOODINSEC_12_14',
'FOODINSEC_15_17',
'VLFOODSEC_12_14',
'VLFOODSEC_15_17']

LOCAL_LIST = [
'FMRKTPTH13',
'FMRKTPTH18',
'FOODHUB18']

HEALTH_LIST = [
'PCT_DIABETES_ADULTS08',
'PCT_DIABETES_ADULTS13',
'PCT_OBESE_ADULTS12',
'PCT_OBESE_ADULTS17',
'PCT_HSPA17',
'RECFACPTH11',
'RECFACPTH16']

SOCIOECONOMIC_LIST = [
'MEDHHINC15',
'POVRATE15',
'PERPOV10',
'CHILDPOVRATE15',
'PERCHLDPOV10',
'METRO13']


GLOBAL_LIST = POPULATION_LIST + ACCESS_LIST + STORES_LIST + RESTAURANTS_LIST + ASSISTANCE_LIST + INSECURITY_LIST + LOCAL_LIST + HEALTH_LIST + SOCIOECONOMIC_LIST

GLOBAL_LIST
# Out:
# ['County',
#  'State',
#  '2010_Census_Population',
#  'Population_Estimate_2011',
#  'Population_Estimate_2012',
#  'Population_Estimate_2013',
#  'Population_Estimate_2014',
#  'Population_Estimate_2015',
#  'Population_Estimate_2016',
#  'Population_Estimate_2017',
#  'Population_Estimate_2018',
#  'FIPS',
#  'PCT_LACCESS_POP10',
#  'PCT_LACCESS_POP15',
#  'PCT_LACCESS_LOWI10',
#  'PCT_LACCESS_LOWI15',
#  'PCT_LACCESS_HHNV10',
#  'PCT_LACCESS_HHNV15',
#  'PCT_LACCESS_SNAP15',
#  'GROCPTH11',
#  'GROCPTH16',
#  'SUPERCPTH11',
#  'SUPERCPTH16',
#  'CONVSPTH11',
#  'CONVSPTH16',
#  'SNAPSPTH12',
#  'SNAPSPTH17',
#  'WICSPTH11',
#  'WICSPTH16',
#  'FFRPTH11',
#  'FFRPTH16',
#  'FSRPTH11',
#  'FSRPTH16',
#  'PC_FFRSALES07',
#  'PC_FFRSALES12',
#  'PC_FSRSALES07',
#  'PC_FSRSALES12',
#  'REDEMP_SNAPS12',
#  'REDEMP_SNAPS17',
#  'PCT_SNAP12',
#  'PCT_SNAP17',
#  'PC_SNAPBEN12',
#  'PC_SNAPBEN17',
#  'SNAP_PART_RATE11',
#  'SNAP_PART_RATE16',
#  'PC_WIC_REDEMP11',
#  'PC_WIC_REDEMP16',
#  'REDEMP_WICS11',
#  'REDEMP_WICS16',
#  'PCT_WIC12',
#  'PCT_WIC17',
#  'PCT_WICINFANTCHILD14',
#  'PCT_WICINFANTCHILD16',
#  'FOOD_BANKS18',
#  'FOODINSEC_12_14',
#  'FOODINSEC_15_17',
#  'VLFOODSEC_12_14',
#  'VLFOODSEC_15_17',
#  'FMRKTPTH13',
#  'FMRKTPTH18',
#  'FOODHUB18',
#  'PCT_DIABETES_ADULTS08',
#  'PCT_DIABETES_ADULTS13',
#  'PCT_OBESE_ADULTS12',
#  'PCT_OBESE_ADULTS17',
#  'PCT_HSPA17',
#  'RECFACPTH11',
#  'RECFACPTH16',
#  'MEDHHINC15',
#  'POVRATE15',
#  'PERPOV10',
#  'CHILDPOVRATE15',
#  'PERCHLDPOV10',
#  'METRO13']

# %%
#### GET THE VARIABLE INFORMATION TO CREATE A TABLE WITH DESCRIPTIONS #####

variables_df = pd.read_csv(VARIABLE_PATH)
variables_df

definitions_df = variables_df.loc[variables_df['Variable Code'].isin(GLOBAL_LIST)]
definitions_df

definitions_clean_df = definitions_df.drop(['Category Name', 'Subcategory Name', 'Geography'], axis=1)
definitions_clean_df
### WRITE VARIABLE DEFINITIONS TO A CSV FILE ###

definitions_clean_df.to_csv('data/ATLAS/definitions.csv')

# %%
### USE THE LISTS ABOVE TO CREATE DATAFRAMES FROM EACH SHEET ###

population_df = global_dict['Supplemental Data - County'][POPULATION_LIST]
access_df = global_dict['ACCESS'][ACCESS_LIST]
store_df = global_dict['STORES'][STORES_LIST]
restaurants_df = global_dict['RESTAURANTS'][RESTAURANTS_LIST]
assistance_df = global_dict['ASSISTANCE'][ASSISTANCE_LIST]
insecurity_df = global_dict['INSECURITY'][INSECURITY_LIST]
local_df = global_dict['LOCAL'][LOCAL_LIST]
health_df = global_dict['HEALTH'][HEALTH_LIST]
socioeconomic_df = global_dict['SOCIOECONOMIC'][SOCIOECONOMIC_LIST]

#access_df.head()

# %%
#### MERGE ALL DATAFRAMES INTO ONE DATAFRAME #####

DATAFRAME_LIST = ['access_df','population_df', 'store_df', 'restaurants_df', 'assistance_df', 'insecurity_df', 'local_df', 'health_df', 'socioeconomic_df']

proposed_merged_df = pd.concat([population_df,access_df, store_df, restaurants_df, assistance_df, insecurity_df, local_df, health_df, socioeconomic_df], axis=1)

proposed_merged_df.shape

proposed_merged_df.head()

proposed_merged_df.dtypes
# Out:
# County                       object
# State                        object
# 2010_Census_Population      float64
# Population_Estimate_2011    float64
# Population_Estimate_2012    float64
#                              ...
# POVRATE15                   float64
# PERPOV10                    float64
# CHILDPOVRATE15              float64
# PERCHLDPOV10                float64
# METRO13                     float64
# Length: 74, dtype: object

# %%
### get a list of datatypes for the merged list

merged_datatypes = proposed_merged_df.dtypes

merged_datatypes
# Out:
# County                       object
# State                        object
# 2010_Census_Population      float64
# Population_Estimate_2011    float64
# Population_Estimate_2012    float64
#                              ...
# POVRATE15                   float64
# PERPOV10                    float64
# CHILDPOVRATE15              float64
# PERCHLDPOV10                float64
# METRO13                     float64
# Length: 74, dtype: object

# %%
# Output the datatypes to a txt file

pd.DataFrame.to_csv(merged_datatypes, '../Local_resources//merged_datatypes.txt',sep=',', na_rep='.', index=True)

# %%
### OUTPUT THE MERGED DATAFRAME TO A CSV FILE ###

proposed_merged_df.to_csv('data/ATLAS/FoodEnvironmentAtlas_proposed.csv')

# %%
proposed_merged_df.hist

proposed_merged_df.describe()
# Out:
#        2010_Census_Population  Population_Estimate_2011  \
# count            3.142000e+03              3.142000e+03
# mean             9.826204e+04              9.916614e+04
# std              3.129467e+05              3.163954e+05
# min              8.200000e+01              9.000000e+01
# 25%              1.111450e+04              1.108700e+04
# 50%              2.587200e+04              2.579450e+04
# 75%              6.678000e+04              6.699225e+04
# max              9.818605e+06              9.876727e+06
#
#        Population_Estimate_2012  Population_Estimate_2013  \
# count              3.142000e+03              3.142000e+03
# mean               9.989631e+04              1.005913e+05
# std                3.195096e+05              3.224247e+05
# min                8.600000e+01              8.900000e+01
# 25%                1.100525e+04              1.101700e+04
# 50%                2.578850e+04              2.571050e+04
# 75%                6.711200e+04              6.740875e+04
# max                9.938436e+06              9.998105e+06
#
#        Population_Estimate_2014  Population_Estimate_2015  \
# count              3.142000e+03              3.142000e+03
# mean               1.013324e+05              1.020823e+05
# std                3.253350e+05              3.281943e+05
# min                8.900000e+01              8.800000e+01
# 25%                1.098550e+04              1.094800e+04
# 50%                2.564200e+04              2.563250e+04
# 75%                6.760700e+04              6.748825e+04
# max                1.004841e+07              1.009704e+07
#
#        Population_Estimate_2016  Population_Estimate_2017  \
# count              3.142000e+03              3.142000e+03
# mean               1.028235e+05              1.034841e+05
# std                3.305395e+05              3.320993e+05
# min                8.800000e+01              8.800000e+01
# 25%                1.093525e+04              1.088900e+04
# 50%                2.571650e+04              2.578400e+04
# 75%                6.730625e+04              6.781575e+04
# max                1.012054e+07              1.011876e+07
#
#        Population_Estimate_2018          FIPS  ...  PCT_OBESE_ADULTS17  \
# count              3.142000e+03   3143.000000  ...         3143.000000
# mean               1.041271e+05  30390.411709  ...           31.862965
# std                3.334863e+05  15164.717720  ...            3.329267
# min                8.800000e+01   1001.000000  ...           22.600000
# 25%                1.092650e+04  18178.000000  ...           30.100000
# 50%                2.575850e+04  29177.000000  ...           32.400000
# 75%                6.782050e+04  45082.000000  ...           33.800000
# max                1.010552e+07  56045.000000  ...           38.100000
#
#         PCT_HSPA17  RECFACPTH11  RECFACPTH16     MEDHHINC15    POVRATE15  \
# count  2383.000000  3143.000000  3143.000000    3139.000000  3139.000000
# mean     24.620520     0.071337     0.070300   48611.206117    16.260975
# std       2.822971     0.073805     0.075829   12351.988288     6.442319
# min      13.400000     0.000000     0.000000   22894.000000     3.400000
# 25%      22.400000     0.000000     0.000000   40438.000000    11.500000
# 50%      24.700000     0.064726     0.061983   46807.000000    15.200000
# 75%      26.500000     0.107117     0.108090   54164.000000    19.700000
# max      30.800000     0.628141     1.053741  125900.000000    47.400000
#
#           PERPOV10  CHILDPOVRATE15  PERCHLDPOV10      METRO13
# count  3143.000000     3139.000000   3143.000000  3143.000000
# mean      0.112313       23.238738      0.225262     0.371301
# std       0.315801        9.364172      0.417822     0.483230
# min       0.000000        3.300000      0.000000     0.000000
# 25%       0.000000       16.250000      0.000000     0.000000
# 50%       0.000000       22.300000      0.000000     0.000000
# 75%       0.000000       29.100000      0.000000     1.000000
# max       1.000000       61.600000      1.000000     1.000000
#
# [8 rows x 72 columns]
