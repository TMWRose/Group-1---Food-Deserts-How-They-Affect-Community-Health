# %%
import pandas as pd
import sqlalchemy 
import numpy as np

# %%
final_df=pd.read_csv('FoodEnvironmentAtlas_proposed.csv')

# %%
final_df
# Out:
#       Unnamed: 0           County     State  2010_Census_Population  \
# 0              0   Autauga County   Alabama                 54571.0
# 1              1   Baldwin County   Alabama                182265.0
# 2              2   Barbour County   Alabama                 27457.0
# 3              3      Bibb County   Alabama                 22915.0
# 4              4    Blount County   Alabama                 57322.0
# ...          ...              ...       ...                     ...
# 3139        3139     Uinta County   Wyoming                 21118.0
# 3140        3140  Washakie County   Wyoming                  8533.0
# 3141        3141    Weston County   Wyoming                  7208.0
# 3142        3142              NaN       NaN                     NaN
# 3143        3143              NaN       NaN                     NaN
#
#       Population_Estimate_2011  Population_Estimate_2012  \
# 0                      55208.0                   54936.0
# ...

# %%
final_df.columns
# Out:
# Index(['Unnamed: 0', 'County', 'State', '2010_Census_Population',
#        'Population_Estimate_2011', 'Population_Estimate_2012',
#        'Population_Estimate_2013', 'Population_Estimate_2014',
#        'Population_Estimate_2015', 'Population_Estimate_2016',
#        'Population_Estimate_2017', 'Population_Estimate_2018', 'FIPS',
#        'PCT_LACCESS_POP10', 'PCT_LACCESS_POP15', 'PCT_LACCESS_LOWI10',
#        'PCT_LACCESS_LOWI15', 'PCT_LACCESS_HHNV10', 'PCT_LACCESS_HHNV15',
#        'PCT_LACCESS_SNAP15', 'GROCPTH11', 'GROCPTH16', 'SUPERCPTH11',
#        'SUPERCPTH16', 'CONVSPTH11', 'CONVSPTH16', 'SNAPSPTH12', 'SNAPSPTH17',
#        'WICSPTH11', 'WICSPTH16', 'FFRPTH11', 'FFRPTH16', 'FSRPTH11',
#        'FSRPTH16', 'PC_FFRSALES07', 'PC_FFRSALES12', 'PC_FSRSALES07',
#        'PC_FSRSALES12', 'REDEMP_SNAPS12', 'REDEMP_SNAPS17', 'PCT_SNAP12',
#        'PCT_SNAP17', 'PC_SNAPBEN12', 'PC_SNAPBEN17', 'SNAP_PART_RATE11',
#        'SNAP_PART_RATE16', 'PC_WIC_REDEMP11', 'PC_WIC_REDEMP16',
# ...

# %%
final_df.dtypes
# Out:
# Unnamed: 0                    int64
# County                       object
# State                        object
# 2010_Census_Population      float64
# Population_Estimate_2011    float64
#                              ...
# POVRATE15                   float64
# PERPOV10                    float64
# CHILDPOVRATE15              float64
# PERCHLDPOV10                float64
# METRO13                     float64
# Length: 75, dtype: object

# %%
final_df['FOODHUB18']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 3139   NaN
# 3140   NaN
# 3141   NaN
# 3142   NaN
# 3143   NaN
# Name: FOODHUB18, Length: 3144, dtype: float64

# %%
final_df['REDEMP_SNAPS12']
# Out:
# 0       301432.081069
# 1       274394.503663
# 2       325496.560766
# 3       356444.032000
# 4       229730.022632
#             ...
# 3139    115388.180952
# 3140    260305.896857
# 3141    132657.990000
# 3142     58482.432289
# 3143              NaN
# Name: REDEMP_SNAPS12, Length: 3144, dtype: float64
