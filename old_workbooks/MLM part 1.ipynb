# %%
import pandas as pd
import numpy as np

# %%
food_Environment_CSV = pd.read_csv('https://raw.githubusercontent.com/TMWRose/Group-1---Food-Deserts-How-They-Affect-Community-Health/Justin/data/Neighborhood_Effects_Food_Environment_Census_Tract_Level.csv')
food_Environment_CSV.head(10)
# Out:
#        GEOID10  CountyCode CountyName  Food_Desert_Tot_Pop  \
# 0  26049000100       26049    Genesse                  NaN
# 1  26049000200       26049    Genesse                  NaN
# 2  26049000300       26049    Genesse                  NaN
# 3  26049000400       26049    Genesse                  NaN
# 4  26049000500       26049    Genesse                  NaN
# 5  26049000600       26049    Genesse                  NaN
# 6  26049000700       26049    Genesse                  NaN
# 7  26049000800       26049    Genesse                  NaN
# 8  26049000900       26049    Genesse                  NaN
# 9  26049001000       26049    Genesse               3861.0
#
#    Food_Desert_Pct_Lowa_Pop  Food_Desert_lowa_Pop  Food_Desert_Pct_Lowi  \
# 0                       NaN                   NaN                   NaN
# 1                       NaN                   NaN                   NaN
# 2                       NaN                   NaN                   NaN
# ...

# %%
community_Health_CSV = pd.read_csv('https://raw.githubusercontent.com/TMWRose/Group-1---Food-Deserts-How-They-Affect-Community-Health/Justin/data/Neighborhood_Effects_Health_Status_Census_Tract_Level.csv', encoding = "latin-1")
community_Health_CSV.head(10)
# Out:
# C:\Users\17027\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (694) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        GEOID10  CountyCode CountyName  YearDX2011  YearDX2009  YearDX2014  \
# 0  26049000100       26049    Genesse          33          34          40
# 1  26049000200       26049    Genesse          31          27          13
# 2  26049000300       26049    Genesse          26          36          26
# 3  26049000400       26049    Genesse          22          23          22
# 4  26049000500       26049    Genesse          19          19          22
# 5  26049000600       26049    Genesse          36          24          35
# 6  26049000700       26049    Genesse          36          26          32
# 7  26049000800       26049    Genesse          11          25          15
# ...
