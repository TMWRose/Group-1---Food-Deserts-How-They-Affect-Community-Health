# %%
import pandas as pd
import sqlalchemy as sql
import config
from sqlalchemy import create_engine

# %%
final_table=pd.read_csv('Resources/FoodEnvironmentAtlas_proposed.csv')

# %%
final_table.head()
# Out:
#    Unnamed: 0          County     State  2010_Census_Population  \
# 0           0  Autauga County   Alabama                 54571.0
# 1           1  Baldwin County   Alabama                182265.0
# 2           2  Barbour County   Alabama                 27457.0
# 3           3     Bibb County   Alabama                 22915.0
# 4           4   Blount County   Alabama                 57322.0
#
#    Population_Estimate_2011  Population_Estimate_2012  \
# 0                   55208.0                   54936.0
# 1                  186540.0                  190143.0
# 2                   27350.0                   27174.0
# 3                   22747.0                   22664.0
# 4                   57554.0                   57570.0
#
#    Population_Estimate_2013  Population_Estimate_2014  \
# 0                   54713.0                   54876.0
# 1                  194886.0                  199189.0
# 2                   26944.0                   26758.0
# ...

# %%
db_string=f'postgresql://postgres:postgres@final-project-db.cvsvn4oapkzs.us-east-2.rds.amazonaws.com:5432/atlas'

# %%
engine=create_engine(db_string)

# %%
final_table.to_sql('atlas', con=engine, index=False, if_exists='replace')
