# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
df = pd.read_csv(Path('/Users/derricknyagesuka/Desktop/Group-2---Food-Deserts-How-They-Affect-Community-Health/FoodEnvrtAtlas.csv'))
df.head(20)
# Out:
#     Unnamed: 0  FIPS  LACCESS_POP10  LACCESS_POP15  LACCESS_LOWI10  \
# 0            0  1001   18428.439690   17496.693040     5344.427472
# 1            1  1003   35210.814080   30561.264430     9952.144027
# 2            2  1005    5722.305602    6069.523628     3135.676086
# 3            3  1007    1044.867327     969.378841      491.449066
# 4            4  1009    1548.175559    3724.428242      609.027708
# 5            5  1011    4089.983548    4141.900365     2199.359828
# 6            6  1013    1307.819706    1304.328756      593.225139
# 7            7  1015   30901.150590   27785.986770    11909.162860
# 8            8  1017    6748.213223    7131.505717     3018.284747
# 9            9  1019      79.410235     103.522499       34.483862
# 10          10  1021    1456.677891    1469.899110      736.957577
# 11          11  1023    2612.253868    2702.895199     1611.534003
# 12          12  1025    5060.660983    5712.926332     2901.694996
# ...

# %%
# Drop state and county columns
df.drop(columns = ['State', 'County'], axis = 1, inplace = True)

# %%
# Set FIPS as our index
df.set_index('FIPS', inplace = True)

# %%
df.head()
# Out:
#       Unnamed: 0  LACCESS_POP10  LACCESS_POP15  LACCESS_LOWI10  \
# FIPS
# 1001           0   18428.439690   17496.693040     5344.427472
# 1003           1   35210.814080   30561.264430     9952.144027
# 1005           2    5722.305602    6069.523628     3135.676086
# 1007           3    1044.867327     969.378841      491.449066
# 1009           4    1548.175559    3724.428242      609.027708
#
#       LACCESS_LOWI15  LACCESS_HHNV10  LACCESS_HHNV15 2010_Census_Population  \
# FIPS
# 1001     6543.676824      664.216487      677.672769                 54,571
# 1003     9886.831137     1571.779915     1394.162766                182,265
# 1005     2948.790251      406.142372      425.144927                 27,457
# 1007      596.162829      275.060875      224.388125                 22,915
# 1009     1650.959482      705.466783      719.931444                 57,322
#
#      Population_Estimate_2011 Population_Estimate_2012  ...  \
# ...

# %%
# Select the columns that we are going to use for our model
selected_columns = ['LACCESS_POP10', 'LACCESS_LOWI10', 'LACCESS_HHNV10', 'PCT_DIABETES_ADULTS08', 
                   'PCT_OBESE_ADULTS12', 'MEDHHINC15', 'POVRATE15', 'FFRPTH11', 'FFRPTH16', 'PCH_FFRPTH_11_16', 
                   'GROCPTH11', 'GROCPTH16', 'PCH_GROCPTH_11_16']

# %%
# Create df with selected_columns
df = df[selected_columns]

# %%
df.shape
# Out:
# (3140, 13)

# %%
# Check for null values and drop them
df.isnull().sum()
# Out:
# LACCESS_POP10             0
# LACCESS_LOWI10            0
# LACCESS_HHNV10            0
# PCT_DIABETES_ADULTS08     5
# PCT_OBESE_ADULTS12        0
# MEDHHINC15                1
# POVRATE15                 1
# FFRPTH11                  0
# FFRPTH16                  0
# PCH_FFRPTH_11_16         52
# GROCPTH11                 0
# GROCPTH16                 0
# PCH_GROCPTH_11_16        16
# dtype: int64

# %%
# Dropping null values
df = df.dropna()

# %%
# Check for null values again
df.isnull().sum()
# Out:
# LACCESS_POP10            0
# LACCESS_LOWI10           0
# LACCESS_HHNV10           0
# PCT_DIABETES_ADULTS08    0
# PCT_OBESE_ADULTS12       0
# MEDHHINC15               0
# POVRATE15                0
# FFRPTH11                 0
# FFRPTH16                 0
# PCH_FFRPTH_11_16         0
# GROCPTH11                0
# GROCPTH16                0
# PCH_GROCPTH_11_16        0
# dtype: int64
